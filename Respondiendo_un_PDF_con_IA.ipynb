# %% [markdown]
# <a href="https://colab.research.google.com/github/laboratoriodecodigos/Colab-Python/blob/main/Respondiendo_un_PDF_con_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install reportlab
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle, PageBreak
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.enums import TA_CENTER
from reportlab.lib.units import inch

path = "/content/documento_prueba_ia_pdf_machine_learning.pdf"

styles = getSampleStyleSheet()
title = ParagraphStyle(
    "TitleCustom", parent=styles["Title"], alignment=TA_CENTER,
    fontSize=20, leading=24, spaceAfter=18
)
h1 = ParagraphStyle(
    "H1Custom", parent=styles["Heading1"], fontSize=15,
    leading=19, spaceBefore=10, spaceAfter=8
)
body = ParagraphStyle(
    "BodyCustom", parent=styles["BodyText"], fontSize=10.5,
    leading=15, spaceAfter=8
)

doc = SimpleDocTemplate(
    path, pagesize=letter,
    rightMargin=50, leftMargin=50, topMargin=50, bottomMargin=50
)

story = []

story.append(Paragraph("Guía práctica de Machine Learning", title))
story.append(Paragraph(
    "<b>Documento de prueba para el proyecto: “IA que responde usando un PDF”</b>",
    body
))
story.append(Paragraph(
    "Este documento contiene información ficticia y educativa diseñada para probar un sistema "
    "de preguntas y respuestas basado en documentos PDF.",
    body
))

story.append(Paragraph("1. ¿Qué es Machine Learning?", h1))
story.append(Paragraph(
    "Machine Learning, o aprendizaje automático, es una rama de la inteligencia artificial "
    "que permite que un sistema aprenda patrones a partir de datos y utilice esos patrones "
    "para realizar predicciones o tomar decisiones.",
    body
))
story.append(Paragraph(
    "Un flujo básico de Machine Learning suele incluir la recopilación de datos, limpieza, "
    "exploración, selección de variables, entrenamiento, evaluación y despliegue del modelo.",
    body
))

story.append(Paragraph("2. Tipos principales de aprendizaje", h1))
data = [
    ["Tipo", "Descripción", "Ejemplo"],
    ["Supervisado", "Aprende utilizando datos con una respuesta conocida.", "Predecir el precio de una vivienda."],
    ["No supervisado", "Busca patrones sin una etiqueta objetivo.", "Agrupar clientes por comportamiento."],
    ["Por refuerzo", "Aprende mediante recompensas y penalizaciones.", "Un agente que aprende a jugar."],
]
table = Table(data, colWidths=[1.1*inch, 2.7*inch, 2.0*inch])
table.setStyle(TableStyle([
    ("BACKGROUND", (0,0), (-1,0), colors.lightgrey),
    ("GRID", (0,0), (-1,-1), 0.5, colors.grey),
    ("FONTNAME", (0,0), (-1,0), "Helvetica-Bold"),
    ("FONTSIZE", (0,0), (-1,-1), 8.5),
    ("VALIGN", (0,0), (-1,-1), "TOP"),
    ("LEFTPADDING", (0,0), (-1,-1), 5),
    ("RIGHTPADDING", (0,0), (-1,-1), 5),
    ("TOPPADDING", (0,0), (-1,-1), 5),
    ("BOTTOMPADDING", (0,0), (-1,-1), 5),
]))
story.append(table)

story.append(PageBreak())

story.append(Paragraph("3. Datos de entrenamiento y prueba", h1))
story.append(Paragraph(
    "Los datos suelen dividirse en conjuntos de entrenamiento y prueba. El conjunto de "
    "entrenamiento se utiliza para ajustar el modelo, mientras que el conjunto de prueba "
    "permite estimar cómo funciona con datos que no utilizó durante el entrenamiento.",
    body
))
story.append(Paragraph(
    "Una división frecuente es utilizar aproximadamente el 80% de los datos para entrenamiento "
    "y el 20% para prueba. La proporción puede cambiar dependiendo del tamaño y las características "
    "del conjunto de datos.",
    body
))

story.append(Paragraph("4. Regresión y clasificación", h1))
story.append(Paragraph(
    "<b>Regresión:</b> se utiliza cuando la variable que queremos predecir es numérica. "
    "Por ejemplo, estimar ventas, temperatura o precio.",
    body
))
story.append(Paragraph(
    "<b>Clasificación:</b> se utiliza cuando queremos asignar una categoría. "
    "Por ejemplo, clasificar un correo como spam o no spam.",
    body
))

story.append(Paragraph("5. Algoritmos comunes", h1))
algos = [
    ["Algoritmo", "Uso frecuente"],
    ["Regresión lineal", "Predicción de valores numéricos con relaciones aproximadamente lineales."],
    ["Árbol de decisión", "Clasificación y regresión mediante reglas de decisión."],
    ["Random Forest", "Combina múltiples árboles para mejorar la robustez de las predicciones."],
    ["K-Means", "Agrupación de datos en grupos o clusters."],
    ["Red neuronal", "Modelado de relaciones complejas; muy utilizada en visión, audio y lenguaje."],
]
table2 = Table(algos, colWidths=[1.7*inch, 4.1*inch])
table2.setStyle(TableStyle([
    ("BACKGROUND", (0,0), (-1,0), colors.lightgrey),
    ("GRID", (0,0), (-1,-1), 0.5, colors.grey),
    ("FONTNAME", (0,0), (-1,-1), "Helvetica-Bold"),
    ("FONTSIZE", (0,0), (-1,-1), 9),
    ("VALIGN", (0,0), (-1,-1), "TOP"),
    ("LEFTPADDING", (0,0), (-1,-1), 5),
    ("RIGHTPADDING", (0,0), (-1,-1), 5),
    ("TOPPADDING", (0,0), (-1,-1), 5),
    ("BOTTOMPADDING", (0,0), (-1,-1), 5),
]))
story.append(table2)

story.append(PageBreak())

story.append(Paragraph("6. Evaluación de modelos", h1))
story.append(Paragraph(
    "Evaluar un modelo permite conocer qué tan bien funciona. En clasificación pueden utilizarse "
    "accuracy, precision, recall y F1-score. En regresión son comunes MAE, MSE y RMSE.",
    body
))
story.append(Paragraph(
    "<b>Accuracy:</b> proporción de predicciones correctas sobre el total de predicciones.",
    body
))
story.append(Paragraph(
    "<b>MAE:</b> error absoluto medio entre los valores reales y las predicciones.",
    body
))
story.append(Paragraph(
    "<b>Overfitting:</b> ocurre cuando el modelo aprende demasiado bien los datos de entrenamiento "
    "y pierde capacidad de generalización frente a datos nuevos.",
    body
))

story.append(Paragraph("7. Ejemplo práctico", h1))
story.append(Paragraph(
    "Supongamos que una universidad quiere predecir la calificación final de un estudiante. "
    "Puede utilizar variables como horas de estudio, porcentaje de asistencia y número de actividades "
    "entregadas. El modelo aprende la relación entre esas variables y las calificaciones históricas.",
    body
))
story.append(Paragraph(
    "Si un nuevo estudiante registra 8 horas de estudio semanales, 90% de asistencia y 9 actividades "
    "entregadas, el modelo puede generar una estimación de su calificación. La predicción no es una "
    "certeza: depende de la calidad de los datos y del desempeño del modelo.",
    body
))

story.append(Paragraph("8. Preguntas para probar la IA", h1))
questions = [
    "¿Qué es Machine Learning?",
    "¿Cuáles son los tres tipos principales de aprendizaje mencionados?",
    "¿Qué diferencia existe entre regresión y clasificación?",
    "¿Qué algoritmo se utiliza para agrupamiento?",
    "¿Qué es overfitting?",
    "¿Qué porcentaje de datos se propone como ejemplo para entrenamiento?",
    "¿Qué métricas se mencionan para evaluar clasificación?",
    "¿Qué variables podría usar una universidad para predecir una calificación?"
]
for q in questions:
    story.append(Paragraph("• " + q, body))

doc.build(story)

print(f"PDF creado: {path}")
# Out:
# ...
# PDF creado: /content/documento_prueba_ia_pdf_machine_learning.pdf

# %% [markdown]
# # **IA que responde usando un PDF**

# %%
# !pip install pypdf
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.1/378.1 kB 7.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()

pdf_path = list(
    uploaded.keys()
)[0]

print(pdf_path)
# Out:
#      <input type="file" id="files-ed396c9f-8fd8-4e13-8403-7f349cd56bef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed396c9f-8fd8-4e13-8403-7f349cd56bef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Extrae el texto
from pypdf import PdfReader

reader = PdfReader(
    pdf_path
)

paginas = []

for numero, pagina in enumerate(
    reader.pages,
    start=1
):

    texto = pagina.extract_text()

    if texto:

        paginas.append({
            "pagina": numero,
            "texto": texto
        })

print(
    "Páginas:",
    len(paginas)
)
# Out:
# Páginas: 3

# %%
#Divide el Texto
chunks = []

for pagina in paginas:

    texto = pagina["texto"]

    tamaño = 800

    for i in range(
        0,
        len(texto),
        tamaño
    ):

        fragmento = texto[
            i:i+tamaño
        ]

        chunks.append({
            "pagina": pagina["pagina"],
            "texto": fragmento
        })

print(
    "Fragmentos:",
    len(chunks)
)
# Out:
# Fragmentos: 6

# %%
#Embeddings
from sentence_transformers import SentenceTransformer

model_embedding = SentenceTransformer(
    "all-MiniLM-L6-v2"
)

textos = [
    c["texto"]
    for c in chunks
]

embeddings = model_embedding.encode(
    textos,
    show_progress_bar=True
)
# Out:
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 75.7 MB/s eta 0:00:00
# ...

# %%
#Faiss

import faiss
import numpy as np

embeddings = np.array(
    embeddings,
    dtype="float32"
)

index = faiss.IndexFlatL2(
    embeddings.shape[1]
)

index.add(
    embeddings
)

# %%
def buscar_pdf(
    pregunta,
    k=1
):

    vector = model_embedding.encode(
        [pregunta]
    )
    vector = np.array(
        vector,
        dtype="float32"
    )

    distancias, indices = index.search(
        vector,
        k
    )

    resultados = []

    for distancia, indice in zip(
        distancias[0],
        indices[0]
    ):
        resultados.append({
            "pagina":
                chunks[indice]["pagina"],

            "texto":
                chunks[indice]["texto"],

            "distancia":
                float(distancia)
        })

    return resultados

# %%
pregunta = input(
    "Pregunta a realizar "
)

resultados = buscar_pdf(
    pregunta
)

for r in resultados:

    print(
        f"\nPágina: {r['pagina']}"
    )

    print(
        r["texto"][:500]
    )
# Out:
# Pregunta a realizar ¿Qué es random Forest?
#
# Página: 2
# o frecuente
# Regresión lineal
# Predicción de valores numéricos con relaciones aproximadamente lineales.
# Árbol de decisión
# Clasificación y regresión mediante reglas de decisión.
# Random Forest
# Combina múltiples árboles para mejorar la robustez de las predicciones.
# K-Means
# Agrupación de datos en grupos o clusters.
# Red neuronal
# Modelado de relaciones complejas; muy utilizada en visión, audio y lenguaje.
